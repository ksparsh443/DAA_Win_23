# %% [markdown]
# <a href="https://colab.research.google.com/github/ksparsh443/DAA_Win_23/blob/main/Assignment2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
car_crashes_data = sns.load_dataset('car_crashes')

# %%
car_crashes_data
# Out:
#     total  speeding  alcohol  not_distracted  no_previous  ins_premium  \
# 0    18.8     7.332    5.640          18.048       15.040       784.55
# 1    18.1     7.421    4.525          16.290       17.014      1053.48
# 2    18.6     6.510    5.208          15.624       17.856       899.47
# 3    22.4     4.032    5.824          21.056       21.280       827.34
# 4    12.0     4.200    3.360          10.920       10.680       878.41
# 5    13.6     5.032    3.808          10.744       12.920       835.50
# 6    10.8     4.968    3.888           9.396        8.856      1068.73
# 7    16.2     6.156    4.860          14.094       16.038      1137.87
# 8     5.9     2.006    1.593           5.900        5.900      1273.89
# 9    17.9     3.759    5.191          16.468       16.826      1160.13
# 10   15.6     2.964    3.900          14.820       14.508       913.15
# 11   17.5     9.450    7.175          14.350       15.225       861.18
# ...

# %%
plt.subplots(figsize=(20,15))
corr=car_crashes_data.corr();
sns.heatmap(corr,annot=True)
# Out:
# <ipython-input-5-94a6c333147b>:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr=car_crashes_data.corr();
# <Axes: >

# %%
sns.boxplot(car_crashes_data.speeding)
# Out:
# <Axes: >

# %%
sns.scatterplot(car_crashes_data)
# Out:
# <Axes: >

# %%
sns.barplot(car_crashes_data)
# Out:
# <Axes: >

# %%
sns.histplot(car_crashes_data)
# Out:
# <Axes: ylabel='Count'>

# %%
sns.countplot(car_crashes_data)
# Out:
# <Axes: ylabel='count'>

# %%
sns.lineplot(car_crashes_data)
# Out:
# <Axes: >

# %%
sns.pairplot(car_crashes_data)

# %% [markdown]
# # New Section
# Heatmap of Correlation Matrix: The heatmap reveals the correlation between different features in the dataset. Features with darker colors indicate higher correlations. For instance, there is a strong positive correlation between 'alcohol' and 'no_previous,' suggesting that states with higher alcohol consumption tend to have more drivers with no previous accidents. Conversely, 'ins_losses' and 'ins_premium' have a negative correlation, implying that states with higher insurance losses tend to have lower insurance premiums.
#
# Box Plot of 'speeding' Column: The box plot illustrates the distribution of the 'speeding' variable. This suggests that speeding rates tend to be consistent across the states represented in the dataset.
#
# Scatter Plot of 'total' vs. 'speeding': The scatter plot does not reveal a clear relationship between 'total' and 'speeding.' There is no apparent trend or correlation between the total number of car crashes and speeding rates across the states.
#
# Bar Plot of 'alcohol' Column: The bar plot displays the average alcohol values by state. 'AK' has the highest average alcohol value, while 'CA' has the lowest. This suggests that Alaska (AK) has a higher average alcohol consumption related to car crashes compared to California (CA).
#
# Histogram of 'ins_premium' Column: The histogram depicts the distribution of insurance premiums. Most premiums are clustered around 800, with a few outliers on the higher end. This indicates that the majority of states have insurance premiums concentrated around a particular value, while a few states have higher premiums.
#
# Count Plot of 'abbrev' Column: The count plot shows the frequency of each state abbreviation in the dataset. There are five entries for different states, with each state represented only once. This implies that the dataset contains information from five distinct states.
#
# Line Plot of 'ins_losses' Over Index: The line plot demonstrates the trend of insurance losses over the index. There is a fluctuating pattern with some variation. This suggests that insurance losses vary over time or across the states, but there is no clear linear trend.
#
# # NOTE THE INFERENCE IS BASED ON THE FIRST FEW VALUES OF THE GRAPH AND NOT TO SCALEl
